# %% [markdown]
# # Análise - Students Performance in Exams
#
# Bom dia, boa tarde, boa noite!
#
# Esse notebook tem como objetivo fazer uma breve análise desse dataset público disponibilizado pelo Kaggle (https://www.kaggle.com/spscientist/students-performance-in-exams).

# %% [markdown]
# #### Carregando bibliotecas necessárias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context("paper")
sns.set_style("darkgrid")
sns.set_palette('RdYlGn')

# %% [markdown]
# #### Iniciando análise

# %%
df = pd.read_csv('StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# Vamos fazer um count nas variáveis, só pra entender a predominancia de gender, race/ethnicity, parental level of education e lunch.

# %%
plt.rcParams['figure.figsize'] = [15, 10]

fig, _ = plt.subplots(2,2)

sns.countplot(x='gender',
              data=df,
              ax=_[0][0])

sns.countplot(x='race/ethnicity',
              data=df,
              ax=_[0][1],
              order=['group A', 'group B', 'group C', 'group D', 'group E'])

sns.countplot(y='parental level of education',
              data=df,
              ax=_[1][0],
              order=['some college', 'some high school', 'high school', "associate's degree", "bachelor's degree", "master's degree"])

_[1][0].set_ylabel('')

sns.countplot(x='lunch',
              data=df,
              ax=_[1][1])

plt.show()

# %% [markdown]
# Ok! Primeiras conclusões:
# <ul>
#     <li> Existem mais mulheres do que homens na escola. </li>
#     <li> A raça/etnia predominante é a C, seguida da D e B. A e E são minoria. </li>
#     <li> A maioria dos pais dos estudantes possuem pouco conhecimento acadêmico (some college) e não possuem bacharelado, apenas alguma especialização (associate's degree) </li>
#     <li> A maioria utiliza lunch padrão. </li>
# </ul>

# %% [markdown]
# Vamos analizar agora o desempenho acadêmico por gênero. Qual o desempenho geral para cada disciplina?

# %%
gender_math_scores = df.groupby('gender')['math score'].mean()
gender_reading_scores = df.groupby('gender')['reading score'].mean()
gender_writing_scores = df.groupby('gender')['writing score'].mean()

# %%
plt.rcParams['figure.figsize'] = [16, 6]

fig, _ = plt.subplots(1,3)

sns.barplot(x=gender_math_scores.index,
            y=gender_math_scores.values,
            ax=_[0])

_[0].title.set_text('Math Scores por gênero (média)')

sns.barplot(x=gender_reading_scores.index,
            y=gender_reading_scores.values,
            ax=_[1])

_[1].title.set_text('Reading Scores por gênero (média)')

sns.barplot(x=gender_writing_scores.index,
            y=gender_writing_scores.values,
            ax=_[2])

_[2].title.set_text('Writing Scores por gênero (média)')

plt.show()

# %% [markdown]
# Conclusões:
# <ul>
#     <li> Os homens possuem uma média de pontuação superior as mulheres na disciplina de matemática </li>
#     <li> As mulheres possuem uma média de pontuação superior aos homens na disciplina de leitura e escrita</li>
# </ul>

# %% [markdown]
# Vamos agora as análises por disciplina.

# %%
fig, _ = plt.subplots(1,3)

sns.scatterplot(x='reading score',
                y='writing score',
                data=df,
                alpha=0.6,
                ax=_[0])

_[0].title.set_text('Reading Score por Writing Score')

sns.scatterplot(x='reading score',
                y='math score',
                data=df,
                alpha=0.6,
                ax=_[1])

_[1].title.set_text('Reading Score por Math Score')

sns.scatterplot(x='writing score',
                y='math score',
                data=df,
                alpha=0.6,
                ax=_[2])

_[2].title.set_text('Writing Score por Math Score')

plt.show()

# %% [markdown]
# Existe uma forte correlação entre a leitura e a escrita. Dessa forma, quem se sai bem na leitura, geralmente se sai bem na escrita também. Essa relação não é tão forte entre leitura e matemática e escrita e matemática. Vamos ver a relação deixando em evidência os gêneros.

# %%
fig, _ = plt.subplots(1,3)

sns.scatterplot(x='reading score',
                y='writing score',
                hue='gender',
                data=df,
                alpha=0.6,
                ax=_[0])

_[0].title.set_text('Reading Score por Writing Score')

sns.scatterplot(x='reading score',
                y='math score',
                hue='gender',
                data=df,
                alpha=0.6,
                ax=_[1])

_[1].title.set_text('Reading Score por Math Score')

sns.scatterplot(x='writing score',
                y='math score',
                hue='gender',
                data=df,
                alpha=0.6,
                ax=_[2])

_[2].title.set_text('Writing Score por Math Score')

plt.show()

# %% [markdown]
# O gráfico acima deixa bem evidente as relações. Homens possuem maiores pontuações em matemática, enquanto mulheres em leitura e escrita. Vamos analisar agora se o tempo de estudo anterior a prova influencia nas notas.

# %%
fig, _ = plt.subplots(1,3)

sns.boxplot(x='test preparation course',
            y='writing score',
            data=df,
            ax=_[0])

_[0].title.set_text('Writing Score por quem estudou ou não')

sns.boxplot(x='test preparation course',
            y='reading score',
            data=df,
            ax=_[1])

_[1].title.set_text('Reading Score por quem estudou ou não')

sns.boxplot(x='test preparation course',
            y='writing score',
            data=df,
            ax=_[2])

_[2].title.set_text('Math Score por quem estudou ou não')

plt.show()

# %% [markdown]
# É! não tem pra onde fugir. Quem se prepara antes, geralmente tem pontuações maiores. Vamos ver a relação entre as notas dos estudantes e o background acadêmico dos pais. Antes disso, vamos criar uma nova coluna no dataframe, a qual possuirá a média geral do estudante, isso é, todas as notas somadas e dividas pra 3.

# %%
df['general mean'] = (df['math score'] + df['writing score'] + df['reading score']) / 3

df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    general mean
# 0     72.666667
# 1     82.333333
# 2     92.666667
# 3     49.333333
# 4     76.333333

# %% [markdown]
# Vamos agora para os plots!

# %%
plt.rcParams['figure.figsize'] = [15, 6]

fig, _ = plt.subplots(1,2)

sns.boxplot(x='parental level of education',
            y='general mean',
            data=df,
            order=['some college', 'some high school', 'high school', "associate's degree", "bachelor's degree", "master's degree"],
            ax=_[0])

_[0].tick_params('x', labelrotation=45)

df_grouped_median = df.groupby('parental level of education')['general mean'].median()

sns.pointplot(x=df_grouped_median.index,
              y=df_grouped_median.values,
              order=['some college', 'some high school', 'high school', "associate's degree", "bachelor's degree", "master's degree"],
              ax=_[1])

_[1].tick_params('x', labelrotation=45)

plt.suptitle('A educação dos pais afeta a média dos alunos?')

plt.show()

# %% [markdown]
# Conclusões:
# <ul>
#     <li> Estudantes com pais com mestrado possuem maiores médias nas pontuações que os demais (Será?)</li>
#     <li> Estudantes com pais entre some high school e high school são os que possuem as piores médias nas pontuações.</li>

# %% [markdown]
# Agora vamos ver se a raça/etnia tem alguma relação com as pontuações dos estudantes.

# %%
fig, _ = plt.subplots(1,2)

sns.boxplot(x='race/ethnicity',
            y='general mean',
            data=df,
            order=['group A', 'group B', 'group C', 'group D', 'group E'],
            ax=_[0])

_[0].tick_params('x', labelrotation=45)

df_grouped_median = df.groupby('race/ethnicity')['general mean'].median()

sns.pointplot(x=df_grouped_median.index,
              y=df_grouped_median.values,
              order=['group A', 'group B', 'group C', 'group D', 'group E'],
              ax=_[1])

_[1].tick_params('x', labelrotation=45)

plt.suptitle('Existem diferenças étnicas entre o desempenho dos estudantes?')

plt.show()

# %% [markdown]
# Aparentemente sim! Possui uma relação linear entre as medianas dos boxplots. Dessa forma, os estudantes do Grupo E possuem maior pontuação que os demais. Os do grupo A são os que possuem menores pontuações.

# %%
fig, _ = plt.subplots(1,2)

gped_median_educ_gender = df.groupby(['parental level of education', 'gender'])['general mean'].median().reset_index()

sns.pointplot(x='parental level of education',
              y='general mean',
              hue='gender',
              data=gped_median_educ_gender,
              order=['some college', 'some high school', 'high school', "associate's degree", "bachelor's degree", "master's degree"],
              ax=_[0])

_[0].title.set_text('Como a educação dos pais afeta a média dos alunos (por gênero)')
_[0].tick_params('x', labelrotation=45)

gped_median_race_gender = df.groupby(['race/ethnicity', 'gender'])['general mean'].median().reset_index()

sns.pointplot(x='race/ethnicity',
              y='general mean',
              hue='gender',
              data=gped_median_race_gender,
              order=['group A', 'group B', 'group C', 'group D', 'group E'],
              ax=_[1])

_[1].title.set_text('Como a etnia afeta nas médias dos alunos (por gênero)')
_[1].tick_params('x', labelrotation=45)

plt.show()

# %% [markdown]
# Aparentemente as mulheres mandam bem em quase todos os cenários. Entretanto, existe uma similiaridade da média dos alunos no grupo E. Vamos analisar agora através de porcentagens. No caso, a porcentagem de estudantes que estudam antes da prova. Se o grupo étnico afeta nisso e se o background dos pais afeta nisso também!

# %%
gped_race_testprep = df.groupby('race/ethnicity')['test preparation course'].value_counts(normalize=True)

# %%
plt.rcParams['figure.figsize'] = [15, 10]

f, _ = plt.subplots(2,3)

def plot_pie(gped_df, group, ax, f_n, s_n):
    
    gped_df.xs(group).plot(kind='pie', autopct='%1.0f%%', ax=ax[f_n][s_n])
    
    ax[f_n][s_n].title.set_text(group)

plot_pie(gped_race_testprep, 'group A', _, 0, 0)
plot_pie(gped_race_testprep, 'group B', _, 0, 1)
plot_pie(gped_race_testprep, 'group C', _, 0, 2)
plot_pie(gped_race_testprep, 'group D', _, 1, 0)
plot_pie(gped_race_testprep, 'group E', _, 1, 1)

_[1][2].set_visible(False)

plt.suptitle('Porcentagem de alunos que estudam antes da prova em cada grupo étnico')

plt.show()

# %% [markdown]
# Aparentemente, a porcentagem de alunos que são do grupo étnico E, é maior que as demais. Por conta disso a média da pontuação desse grupo étnico é maior! Vamos ver o background acadêmico dos pais agora.

# %%
gped_educ_testprep = df.groupby('parental level of education')['test preparation course'].value_counts(normalize=True)

# %%
f, _ = plt.subplots(2,3)

plot_pie(gped_educ_testprep, 'some college', _, 0, 0)
plot_pie(gped_educ_testprep, 'some high school', _, 0, 1)
plot_pie(gped_educ_testprep, 'high school', _, 0, 2)
plot_pie(gped_educ_testprep, "associate's degree", _, 1, 0)
plot_pie(gped_educ_testprep, "bachelor's degree", _, 1, 1)
plot_pie(gped_educ_testprep, "master's degree", _, 1, 2)

plt.suptitle('Porcentagem de alunos que estudam antes da prova de acordo com o background acadêmico dos pais')

plt.show()

# %% [markdown]
# Os alunos que possuem pais com high school incompleto, geralmente, realizam os testes preparatórios das provas mais que os demais. O motivo disso? Não sei. Mas cabem especulações.
